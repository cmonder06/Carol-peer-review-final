# %% [markdown]
# ***CO Final Peer Review***

# %% [markdown]
# **Introduction to Tools for Data Science**

# %% [markdown]
# **Top 12 Data Science Languages**
#
# 1. Python
# 2. R
# 3. SQL
# 4. Java
# 5. Julia
# 6. C
# 7. C++
# 8. JavaScript
# 9. Swift
# 10. Go
# 11. MATLAB
# 12. SAS

# %% [markdown]
# **Top 20 Data Science Libraries**
#
# 1. TensorFlow
# 2. NumPy
# 3. SciPy
# 4. Pandas
# 5. Matplotlib
# 6. Keras
# 7. SciKit-Learn
# 8. PyTorch
# 9. Scrapy
# 10. BeautifulSoup
# 11. LightGBM
# 12. ELI5
# 13. Theano
# 14. NuPIC
# 15. Ramp
# 16. Pipenv
# 17. Bob
# 18. PyBrain
# 19. Caffe2
# 20. Chainer

# %% [markdown]
# **Table of Data Science Tools**
#
# |---Python Data Science Tools---|
# 1. Matplotlib
# 2. Pandas
# 3. NumPy
# 4. Sci-Kit Learn
# 5. Scrapy
# |---Open-Source Data Science Tools---|
# 6. Knime
# 7. WEKA
# 8. Apache Hadoop
# 9. TensorFlow
# 10 Apache Spark
# |---other popular Data Science Tools---|
# 11. Jupyter Notebook
# 12. Tableau
# 13. RapidMiner
# 14. MATLAB
# 15. SAS

# %% [markdown]
# *Introduction to arithmetic expression examples*

# %%
funtion multiplyBy()
{
    num1=document. getElementByld(10).value;
    num2=document. getElemmentByld(20).value;
    document. getElementByld(200).innerHTML=num1*num2;
}

function additionBy()
{
    num1 = document.getElementByID (10).value;
    num2 = document.getElementByID (20).value;
    document.getElementByID(30).innerHTML = num1+num2;
}
# Out:
#   Input In [25]
#     *Multiply and add Numbers*
#               ^
# SyntaxError: invalid syntax

# %%
funtion timeConvert(n) {
    var num = n;
    var hours = (num/60);
    var rhours = Math.floor(hours);
    var minutes = (hours - rhours) * 60;
    vars rminutes = Math.round(minutes);
    return num + " minutes = "+ rhours +"hour(s) and"
    + rminutes + " minute(s).";
}

console,log(time/convert(200));
# Out:
#   Input In [26]
#     funtion timeConvert(n) {
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# *Markdown List of Objectives*
#
# - list Title of Notebook
# - create cell for introduction
# - list Data Science Languages
# - LIst Data Science Libraries
# - create a table of Data Science Tools
# - Intoduction cell for Arithmetic Expression Examples
# - list code that multiplies and adds numbers
# - create a code that converts minutes to hours
# - use a cell for author name
# - share notebook to GitHub
# - remember to screen shot first page of notebook

# %% [markdown]
# **AuthorsName**
# **Carol Onderak*
